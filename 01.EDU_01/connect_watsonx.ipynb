# %% [markdown]
# 1. Python 연결을 위한 Watsonx Project ID, API KEY 준비
# 2. Watsonx Prompt Lab을 활용한 에이전트 개발
# 3. VSCode에서 .env 파일에 Project ID, Key 저장
# 4. IBM 및 Prompt Lab 연결 및 실습 진행

# %% [markdown]
# 1. Watsonx 연결해 LLM 모델 정의
# 2. Prompt 기본 사용법 실습
# 3. Langchain 사용법 실습
# 4. Langchain Watsonx 연결 및 ToolCalling 실습

# %% [markdown]
# 1. 지식 + 정보를 조합한 Websearch tool + wiki
# 2. 주식 정보를 조합한 yfinance + yfinance news tool
# 3. 날씨와 위치 기반 서비스의 조합 weather + googleplacestool -> langchain-google-community 라이브러리 설치 필요
# (google places tool : 특정 지역 식당, 회사 위치, 영업시간, 리뷰 평점 등 조회 가능)
